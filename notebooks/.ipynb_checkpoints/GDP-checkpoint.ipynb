# %% [markdown]
# **Dataset GDP per Capita - Population - Combined Medal Count**
#
# QUESTION 1
# Overall, within scope, what countries have historically won the most medals (irrespective of season)?
#
# What are those winning countries:
# GDP per capita
# Population
#
# Look to see if countries with higher GDP per capita produce more/better Olympic athletes? How much more in terms of GDP per capita would you have to spend to get to the next medal?
#
# Look to see if countries with a higher population produce more Olympic athletes? If so, how many more people are needed to get to the next medal?

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pwd
# Out:
# '/Users/sashacrowe/codebase-ih/Project1---Ironhack/notebooks'

# %% [markdown]
# **First look at the WBD GDP per Capita**
# - initialise df
# - quick peak at first 5 rows
# - where are the nulls -> Unnamed: 68 can be dropped
# - df shape = rows 266, 69 columns
#
# then
# - clean the columun names -> lower case & replace " " with _
# - drop unneeded columns -> Unnamed: 68, Indicator Name, Indicator Code, years 1960-1983

# %%
gdp_df = pd.read_csv("../data/raw/WBD_GDP_DF.csv")

# %%
gdp_df.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  162.342517  166.263682  171.961916  182.018479  192.639989
# 2  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 3  NY.GDP.PCAP.CD  122.193931  127.732834  134.130071  139.291222  148.821355
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
gdp_df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              128
# 1961              124
# 1962              122
# 1963              122
# 1964              122
# 1965              112
# 1966              111
# 1967              108
# 1968              107
# 1969              107
# 1970               85
# 1971               84
# 1972               84
# 1973               84
# 1974               84
# 1975               80
# 1976               80
# 1977               77
# 1978               78
# 1979               77
# 1980               69
# 1981               68
# 1982               66
# 1983               65
# 1984               63
# 1985               61
# 1986               61
# 1987               54
# 1988               50
# 1989               46
# 1990               30
# 1991               30
# 1992               27
# 1993               23
# 1994               22
# 1995               19
# 1996               19
# ...

# %%
gdp_df.shape
# Out:
# (266, 69)

# %%
# lower case the column names
gdp_df.columns = gdp_df.columns.str.lower()

# %%
gdp_df.columns = gdp_df.columns.str.replace(" ","_")

# %%
gdp_df.columns
# Out:
# Index(['country_name', 'country_code', 'indicator_name', 'indicator_code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'unnamed:_68'],
#       dtype='object')

# %%
nu_gdp_df = gdp_df.drop(columns=['indicator_name','indicator_code','unnamed:_68','1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983'])

# %%
nu_gdp_df.columns
# Out:
# Index(['country_name', 'country_code', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %% [markdown]
# **First look at the WBD Population per Country**
# - initialise df
# - quick peak at first 5 rows
# - where are the nulls -> Unnamed: 68 can be dropped
# - df shape = rows 266, 69 columns
#
# then
# - clean the columun names -> lower case & replace " " with _
# - drop unneeded columns -> Unnamed: 68, Indicator Name, Indicator Code, years 1960-1983

# %%
pop_df = pd.read_csv("../data/raw/WBD_POP_DF.csv")

# %%
pop_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965         1966         1967         1968         1969  \
# ...

# %%
pop_df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
# 1961                2
# 1962                2
# 1963                2
# 1964                2
# 1965                2
# 1966                2
# 1967                2
# 1968                2
# 1969                2
# 1970                2
# 1971                2
# 1972                2
# 1973                2
# 1974                2
# 1975                2
# 1976                2
# 1977                2
# 1978                2
# 1979                2
# 1980                2
# 1981                2
# 1982                2
# 1983                2
# 1984                2
# 1985                2
# 1986                2
# 1987                2
# 1988                2
# 1989                2
# 1990                1
# 1991                1
# 1992                1
# 1993                1
# 1994                1
# 1995                1
# 1996                1
# ...

# %%
pop_df.shape
# Out:
# (266, 69)

# %%
# lower case the column names
pop_df.columns = pop_df.columns.str.lower()

# %%
pop_df.columns = pop_df.columns.str.replace(" ","_")

# %%
pop_df.columns
# Out:
# Index(['country_name', 'country_code', 'indicator_name', 'indicator_code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'unnamed:_68'],
#       dtype='object')

# %%
nu_pop_df = pop_df.drop(columns=['indicator_name','indicator_code','unnamed:_68','1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1985','1986','1987','1989',])

# %%
nu_pop_df.columns
# Out:
# Index(['country_name', 'country_code', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %% [markdown]
# **First Look at Medals DF**
# - initialise df
# - quick peak at first 5 rows
# - where are the nulls -> Unnamed: 68 can be dropped
# - df shape = rows 266, 69 columns
#
# then
#
# - clean the columun names -> lower case & replace " " with _
# - country -> country_name

# %%
medals_df = pd.read_csv("../data/raw/Olympic_Games_Medal_Tally.csv")

# %%
medals_df.head()
# Out:
#                 edition  edition_id  year        country country_noc  gold  \
# 0  1896 Summer Olympics           1  1896  United States         USA    11
# 1  1896 Summer Olympics           1  1896         Greece         GRE    10
# 2  1896 Summer Olympics           1  1896        Germany         GER     6
# 3  1896 Summer Olympics           1  1896         France         FRA     5
# 4  1896 Summer Olympics           1  1896  Great Britain         GBR     2
#
#    silver  bronze  total
# 0       7       2     20
# 1      18      19     47
# 2       5       2     13
# 3       4       2     11
# 4       3       2      7

# %%
medals_df.isnull().sum()
# Out:
# edition        0
# edition_id     0
# year           0
# country        0
# country_noc    0
# gold           0
# silver         0
# bronze         0
# total          0
# dtype: int64

# %%
medals_df.shape
# Out:
# (1807, 9)

# %%
medals_df.columns
# Out:
# Index(['edition', 'edition_id', 'year', 'country', 'country_noc', 'gold',
#        'silver', 'bronze', 'total'],
#       dtype='object')

# %%
medals_df = medals_df.rename(columns={'country': 'country_name'})
medals_df.columns
# Out:
# Index(['edition', 'edition_id', 'year', 'country_name', 'country_noc', 'gold',
#        'silver', 'bronze', 'total'],
#       dtype='object')

# %%
nu_pop_df['country_code'].unique()
# Out:
# array(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE',
#        'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL',
#        'BEN', 'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ',
#        'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN',
#        'CEB', 'CHE', 'CHI', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG',
#        'COL', 'COM', 'CPV', 'CRI', 'CSS', 'CUB', 'CUW', 'CYM', 'CYP',
#        'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'EAP', 'EAR',
#        'EAS', 'ECA', 'ECS', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP', 'EST',
#        'ETH', 'EUU', 'FCS', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB',
#        'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC',
#        'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HPC',
#        'HRV', 'HTI', 'HUN', 'IBD', 'IBT', 'IDA', 'IDB', 'IDN', 'IDX',
#        'IMN', 'IND', 'INX', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA',
# ...

# %%
medals_df['country_noc'].unique()
# Out:
# array(['USA', 'GRE', 'GER', 'FRA', 'GBR', 'HUN', 'AUT', 'AUS', 'DEN',
#        'SUI', 'MIX', 'BEL', 'ITA', 'NED', 'CUB', 'ESP', 'NOR', 'IND',
#        'BOH', 'SWE', 'CAN', 'ANZ', 'RUS', 'FIN', 'RSA', 'EST', 'BRA',
#        'JPN', 'LUX', 'TCH', 'NZL', 'YUG', 'ARG', 'URU', 'IRL', 'POL',
#        'HAI', 'MON', 'POR', 'ROU', 'EGY', 'CHI', 'PHI', 'MEX', 'LAT',
#        'TUR', 'JAM', 'PER', 'SRI', 'TTO', 'PAN', 'KOR', 'IRI', 'PUR',
#        'URS', 'LBN', 'BUL', 'VEN', 'ISL', 'PAK', 'BAH', 'ETH', 'UAR',
#        'TPE', 'GHA', 'MAR', 'SGP', 'WIF', 'IRQ', 'TUN', 'KEN', 'NGR',
#        'GDR', 'FRG', 'MGL', 'UGA', 'CMR', 'PRK', 'COL', 'NIG', 'BER',
#        'THA', 'ZIM', 'TAN', 'GUY', 'CHN', 'CIV', 'SYR', 'ALG', 'DOM',
#        'ZAM', 'SUR', 'CRC', 'INA', 'AHO', 'SEN', 'ISV', 'DJI', 'EUN',
#        'LTU', 'NAM', 'CRO', 'IOA', 'ISR', 'SLO', 'MAS', 'QAT', 'UKR',
#        'CZE', 'KAZ', 'BLR', 'SCG', 'SVK', 'ARM', 'BDI', 'ECU', 'HKG',
# ...

# %% [markdown]
# **OJO** | the country_noc & country_code are not the same

# %% [markdown]
# **Combining DFs**

# %%
nu_gdp_df.head()
# Out:
#                   country_name country_code        1984        1985  \
# 0                        Aruba          ABW         NaN         NaN
# 1  Africa Eastern and Southern          AFE  638.748097  534.636572
# 2                  Afghanistan          AFG         NaN         NaN
# 3   Africa Western and Central          AFW  745.326947  762.111295
# 4                       Angola          AGO         NaN         NaN
#
#           1986         1987         1988          1989          1990  \
# 0  6283.001443  7567.253642  9274.514156  10767.396220  11638.733706
# 1   560.769812   653.141414   690.218354    712.241039    810.646700
# 2          NaN          NaN          NaN           NaN           NaN
# 3   588.180369   588.670593   567.573163    516.079428    598.393655
# 4          NaN          NaN          NaN           NaN           NaN
#
#            1991          1992          1993          1994          1995  \
# ...

# %%
nu_pop_df.head()
# Out:
#                   country_name country_code         1984         1985  \
# 0                        Aruba          ABW      64174.0      64478.0
# 1  Africa Eastern and Southern          AFE  260209149.0  267938123.0
# 2                  Afghanistan          AFG   10243686.0   10512221.0
# 3   Africa Western and Central          AFW  176054495.0  180817312.0
# 4                       Angola          AGO    9617702.0    9970621.0
#
#           1986         1987         1988         1989         1990  \
# 0      64553.0      64450.0      64332.0      64596.0      65712.0
# 1  276035920.0  284490394.0  292795186.0  301124880.0  309890664.0
# 2   10448442.0   10322758.0   10383460.0   10673168.0   10694796.0
# 3  185720244.0  190759952.0  195969722.0  201392200.0  206739024.0
# 4   10332574.0   10694057.0   11060261.0   11439498.0   11828638.0
#
#           1991         1992         1993         1994         1995  \
# 0      67864.0      70192.0      72360.0      74710.0      77050.0
# ...

# %%
pd.concat([
    nu_pop_df.set_index('country_name').stack().rename('population'),
    nu_gdp_df.set_index('country_name').stack().rename('gdp_pc')
], axis=1).reset_index()
# Out:
#                                             country_name       level_1  \
# 0                                                  Aruba  country_code
# 1                                                  Aruba          1984
# 2                                                  Aruba          1985
# 3                                                  Aruba          1986
# 4                                                  Aruba          1987
# 5                                                  Aruba          1988
# 6                                                  Aruba          1989
# 7                                                  Aruba          1990
# 8                                                  Aruba          1991
# 9                                                  Aruba          1992
# 10                                                 Aruba          1993
# 11                                                 Aruba          1994
# ...
